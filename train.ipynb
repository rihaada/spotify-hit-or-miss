# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import joblib

# %%
# Load dataset
data = pd.read_csv('dataset/dataset.csv')

# %%
# Split into train and val+test set
from sklearn.model_selection import train_test_split
random_seed = 1234
# Split the training dataset into 60% train and 40% rest
Xtrain, Xrest, ytrain, yrest = train_test_split(
    data.drop(columns=['popularity']), data.popularity, test_size=0.4, random_state=random_seed
)

# Split the rest of the data into 0.6*0.4=24% validation, 0.4*0.4=16% test
Xtest, Xval, ytest, yval = train_test_split(
    Xrest, yrest, test_size=0.6, random_state=random_seed
)

# %%
Xtrain.head()
# Out:
#         Unnamed: 0                track_id                    artists  \
# 30697        30697  2AwTFpFcTm9TyOXqu2OZ8D           Brando;Ninetails
# 31100        31100  4pTkDIlpFNoeWbahu8pVXW  Izzamuzzic;Julien Marchal
# 18722        18722  166cClX0R9SpSz2DxwznPO          Rodney Carrington
# 11627        11627  1BXAyGazbybUVNQ0VmGsdl                Jessie Ware
# 105872      105872  11fv524w8Nyhj7JhzBykor                 Justnormal
#
#                      album_name                        track_name  \
# 30697   Armada Music - ADE 2022  Saturday Night (Feel The Groove)
# 31100                  Shootout                          Shootout
# 18722                  Nut Sack                      Intro - Live
# 11627             Free Yourself                     Free Yourself
# 105872              Reminiscing                         Schwaggel
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# ...

# %%
# Drop columns, (We want to keep only api accessable columns, also drop unnecessary)
api_features = [
    'danceability', 'energy', 'key', 'loudness', 'mode',
    'speechiness', 'acousticness', 'instrumentalness', 'liveness',
    'valence', 'tempo', 'duration_ms', 'time_signature'
]

data_clean = data[api_features]

# %%
data_clean
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1              0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2              0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3              0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4              0.618  0.4430    2    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.172  0.2350    5   -16.393     1       0.0422        0.6400
# 113996         0.174  0.1170    0   -18.318     0       0.0401        0.9940
# 113997         0.629  0.3290    0   -10.895     0       0.0420        0.8670
# 113998         0.587  0.5060    7   -10.889     1       0.0297        0.3810
# 113999         0.526  0.4870    1   -10.204     0       0.0725        0.6810
#
# ...
